# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
max_features = 10000   # vocabulary size
max_len = 200          # sequence length

(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(
    num_words=max_features
)

# %%
x_train = keras.preprocessing.sequence.pad_sequences(
    x_train, maxlen=max_len
)
x_test = keras.preprocessing.sequence.pad_sequences(
    x_test, maxlen=max_len
)

# %% [markdown]
# ### MODEL 1: SIMPLE RNN

# %%
model_rnn = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),
    layers.SimpleRNN(64),
    layers.Dense(1, activation="sigmoid")
])

model_rnn.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model_rnn.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
model_rnn.evaluate(x_test, y_test)

# %% [markdown]
# ### MODEL 2: LSTM

# %%
model_lstm = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),
    layers.LSTM(64),
    layers.Dense(1, activation="sigmoid")
])

model_lstm.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model_lstm.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
model_lstm.evaluate(x_test, y_test)

# %% [markdown]
# ### MODEL 3: GRU

# %%
model_gru = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),
    layers.GRU(64),
    layers.Dense(1, activation="sigmoid")
])

model_gru.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model_gru.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
model_gru.evaluate(x_test, y_test)

# %% [markdown]
# ### MODEL 4: BIDIRECTIONAL LSTM (ADVANCED)

# %%
model_bilstm = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),
    layers.Bidirectional(layers.LSTM(64)),
    layers.Dense(1, activation="sigmoid")
])

model_bilstm.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model_bilstm.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
model_bilstm.evaluate(x_test, y_test)

# %% [markdown]
# ### MODEL 5: BIDIRECTIONAL GRU (ADVANCED + FAST)

# %%
model_bigru = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),
    layers.Bidirectional(layers.GRU(64)),
    layers.Dense(1, activation="sigmoid")
])

model_bigru.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model_bigru.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
model_bigru.evaluate(x_test, y_test)

# %% [markdown]
# ### DEEP STACKED LSTM

# %%
model_stacked_lstm = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),

    layers.LSTM(128, return_sequences=True),
    layers.LSTM(64, return_sequences=True),
    layers.LSTM(32),

    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### DEEP STACKED GRU (FASTER)

# %%
model_stacked_gru = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),

    layers.GRU(128, return_sequences=True),
    layers.GRU(64, return_sequences=True),
    layers.GRU(32),

    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### DEEP BIDIRECTIONAL STACKED LSTM (ADVANCED)

# %%
model_bi_stacked = keras.Sequential([
    layers.Embedding(max_features, 128, input_length=max_len),

    layers.Bidirectional(layers.LSTM(128, return_sequences=True)),
    layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
    layers.Bidirectional(layers.LSTM(32)),

    layers.Dense(1, activation="sigmoid")
])

# %%
any_model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
